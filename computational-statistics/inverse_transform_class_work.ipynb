# %%
set.seed(123)

# %%
# step 3 - generate random variables
n = 1000

a = runif(n)

# %%
hist(a, main="uniform samples")
# Out:
# Plot with title "uniform samples"

# %%
# step 4 x = f-1(u)
x = (a)^(1/3)

# %%
hist(x, main="Sample from f(x)=3x^2", prob=TRUE)
l_x = seq(from=0, to=5, length=100)
lines(l_x, 3*(l_x^2))
# Out:
# Plot with title "Sample from f(x)=3x^2"
