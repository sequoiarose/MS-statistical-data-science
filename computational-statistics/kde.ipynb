# %%
x = iris$Petal.Length
h = bw.ucv(x)

# %%
hist(x, prob=TRUE)
lines(density(x, bw = h))
lines(density(x), col = "blue")
lines(density(x, bw="SJ"), col = "hot pink")
# Out:
# Plot with title "Histogram of x"
